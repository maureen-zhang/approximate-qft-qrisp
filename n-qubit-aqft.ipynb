# %% [markdown]
# # Approximate QFT on 6 Qubits
#
# In this Jupyter notebook, we implement AQFT Circuit 1 from Park-Ahn, with $n $ qubits, error $\varepsilon $.

# %%
from qrisp import QuantumSession, QuantumVariable, QuantumCircuit, prepare, h, z, s, cx, gidney_adder, QFT, barrier

from qrisp import gate_wrap

import matplotlib.pyplot as plt

import numpy as np

# %% [markdown]
# # The input Qubit
# We initialize the circuit with a quantum register containing (n) qubits and a prepared ancilla register containing (b+1) qubits, where
#
# $$
# b = \left\lceil \log_2\left(\frac{n}{\epsilon}\right) \right\rceil.
# $$

# %%
n = 6                                          # n = number of qubits we are applying the AQFT to
epsilon = 0.2                                  # epsilon = spectral norm error tolerance for the approximation
b = int(np.ceil(np.log2(n/epsilon)))           # b + 1 = number of ancilla qubits needed

# %% [markdown]
# ## Adder Gate
# We use the adder gate using the gidney_adder function from the qrisp library. We will wrap it as the "adder" gate

# %%
@gate_wrap
def adder(a, b): 
    gidney_adder(a, b)

# %% [markdown]
# ## Fan Out
#
# The following method applied a fan-out gate as defined in Park-Ahn, which is a sequence of CX gates controlled by a single qubit.

# %%
def fan_out(circuit, control, targets):
    """Fan-out operation using CNOT gates.
    
        Input: circuit -> QuantumCircuit object
               qubit_index -> index of the qubit to fan out from
               ancilla_indices -> list of indices of the ancilla qubits to fan out to

        Output: None
    
    """
    for target in targets:
        circuit.cx(control, target)

# %% [markdown]
# ## AQFT Circuit

# %% [markdown]
# We initialize the circuit with one quantum register on $n$ qubits; and one ancilla register on $b + 1$ qubits.

# %%
qs = QuantumSession()

quantumRegister = QuantumVariable(n, name='q', qs = qs)          # quantum register of n qubits
ancillaRegister = QuantumVariable(int(b+1), name='a', qs = qs)   # ancilla register of b+1 qubits

# %% [markdown]
# We assume that we have access to the correct state for ancilla register.

# %%
# This is done by preparing the ancilla register in the state |1>^(b+1) using the prepare function from qrisp.
allOnesAmplitudes = np.array([0]*(2**(b+1) - 1) + [1], dtype=float)
allOnes = prepare(ancillaRegister, allOnesAmplitudes)  # prepare the ancilla register in the state |1>^(b+1)

# We apply inverse Quantum Fourier Transform to the all ones state to prepare the ancilla correctly for use with Gidney adder
QFT(ancillaRegister, inv=True, qiskit_endian=False)  # apply the inverse QFT to the ancilla register
# Out:
# <QuantumVariable 'a'>

# %% [markdown]
# We implement AQFT Circuit 1 from Park-Ahn, Figure 3.

# %%
h(quantumRegister[0])  # apply Hadamard gate to the first qubit
z(quantumRegister[0])  # apply Z gate to the first qubit

for i in range(1, n):
    s(quantumRegister[i])  # apply S gate to the i-th qubit

for i in range(1,3):
    adder(quantumRegister[0:b], ancillaRegister)    # apply the Gidney adder
    fan_out(qs, quantumRegister[0], quantumRegister[1:b])  # apply the fan-out operation to the first qubit and the ancilla register

barrier(quantumRegister)

for i in range(1, n-1):
    h(quantumRegister[i])  # apply Hadamard gate to the i-th qubit
    s(quantumRegister[i])

    fan_out(qs, quantumRegister[i], quantumRegister[i+1:np.min([i+b,n])])  # apply the fan-out operation to the i-th qubit and the ancilla register
    adder(quantumRegister[i:np.min([i+b,n])], ancillaRegister)  # apply the Gidney adder
    fan_out(qs, quantumRegister[i], quantumRegister[i+1:np.min([i+b,n])])  # apply the fan-out operation to the i-th qubit and the ancilla register again
    barrier(quantumRegister)

h(quantumRegister[n-1])  # apply Hadamard gate to the last qubit

for i in range(n):
    s(quantumRegister[i])  # apply S gate to the i-th qubit

adder(quantumRegister[-1:-b-1:-1], ancillaRegister)  # apply the Gidney adder again


aqft_circuit = qs.to_qiskit()
aqft_circuit.draw(output='mpl', style={'backgroundcolor': '#EEEEEE'}, fold=100, idle_wires=False)
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[18], line 31
#      27 adder(quantumRegister[-1:-b-1:-1], ancillaRegister)  # apply the Gidney adder again
#      28
#      29
#      30 aqft_circuit = qs.to_qiskit()
# ---> 31 aqft_circuit.draw(output='mpl', style={'backgroundcolor': '#EEEEEE'}, fold=100, idle_wires=False)
#
# File ~/Code/Quantum/approximate-qft-qrisp/.venv/lib/python3.14/site-packages/qiskit/circuit/quantumcircuit.py:4048, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#    3903 r"""Draw the quantum circuit. Use the output parameter to choose the drawing format:
#    3904
#    3905 ``text``
#    (...)   4043        qc.draw(output='mpl', style={'backgroundcolor': '#EEEEEE'})
#    4044 """
#    4046 from qiskit.visualization import circuit_drawer
# -> 4048 return circuit_drawer(
#    4049     self,
#    4050     scale=scale,
#    4051     filename=filename,
#    4052     style=style,
#    4053     output=output,
#    4054     interactive=interactive,
#    4055     plot_barriers=plot_barriers,
#    4056     reverse_bits=reverse_bits,
#    4057     justify=justify,
#    4058     vertical_compression=vertical_compression,
#    4059     idle_wires=idle_wires,
#    4060     with_layout=with_layout,
#    4061     fold=fold,
#    4062     ax=ax,
#    4063     initial_state=initial_state,
#    4064     cregbundle=cregbundle,
#    4065     wire_order=wire_order,
#    4066     expr_len=expr_len,
#    4067     barrier_label_len=barrier_label_len,
#    4068     measure_arrows=measure_arrows,
#    4069 )
#
# File ~/Code/Quantum/approximate-qft-qrisp/.venv/lib/python3.14/site-packages/qiskit/visualization/circuit/circuit_visualization.py:368, in circuit_drawer(circuit, scale, filename, style, output, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     352     return _generate_latex_source(
#     353         circuit,
#     354         filename=filename,
#    (...)    365         barrier_label_len=barrier_label_len,
#     366     )
#     367 elif output == "mpl":
# --> 368     image = _matplotlib_circuit_drawer(
#     369         circuit,
#     370         scale=scale,
#     371         filename=filename,
#     372         style=style,
#     373         plot_barriers=plot_barriers,
#     374         reverse_bits=reverse_bits,
#     375         justify=justify,
#     376         idle_wires=idle_wires,
#     377         with_layout=with_layout,
#     378         fold=fold,
#     379         ax=ax,
#     380         initial_state=initial_state,
#     381         cregbundle=cregbundle,
#     382         wire_order=complete_wire_order,
#     383         expr_len=expr_len,
#     384         measure_arrows=measure_arrows,
#     385         barrier_label_len=barrier_label_len,
#     386     )
#     387 else:
#     388     raise VisualizationError(
#     389         f"Invalid output type {output} selected. The only valid choices "
#     390         "are text, latex, latex_source, and mpl"
#     391     )
#
# File ~/Code/Quantum/approximate-qft-qrisp/.venv/lib/python3.14/site-packages/qiskit/visualization/circuit/circuit_visualization.py:776, in _matplotlib_circuit_drawer(circuit, scale, filename, style, plot_barriers, reverse_bits, justify, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     773 if fold is None:
#     774     fold = 25
# --> 776 qcd = _matplotlib.MatplotlibDrawer(
#     777     qubits,
#     778     clbits,
#     779     nodes,
#     780     circuit,
#     781     scale=scale,
#     782     style=style,
#     783     reverse_bits=reverse_bits,
#     784     plot_barriers=plot_barriers,
#     785     fold=fold,
#     786     ax=ax,
#     787     initial_state=initial_state,
#     788     cregbundle=cregbundle,
#     789     with_layout=with_layout,
#     790     expr_len=expr_len,
#     791     barrier_label_len=barrier_label_len,
#     792     measure_arrows=measure_arrows,
#     793 )
#     794 return qcd.draw(filename)
#
# File ~/Code/Quantum/approximate-qft-qrisp/.venv/lib/python3.14/site-packages/qiskit/utils/classtools.py:111, in _WrappedMethod.__get__.<locals>.out(*args, **kwargs)
#     108 @functools.wraps(method)
#     109 def out(*args, **kwargs):
#     110     for callback in self._before:
# --> 111         callback.__get__(obj, objtype)(*args, **kwargs)
#     112     retval = method(*args, **kwargs)
#     113     for callback in self._after:
#
# File ~/Code/Quantum/approximate-qft-qrisp/.venv/lib/python3.14/site-packages/qiskit/utils/lazy_tester.py:42, in _RequireNow.__call__(self, *_args, **_kwargs)
#      41 def __call__(self, *_args, **_kwargs):
# ---> 42     self._tester.require_now(self._feature)
#
# File ~/Code/Quantum/approximate-qft-qrisp/.venv/lib/python3.14/site-packages/qiskit/utils/lazy_tester.py:222, in LazyDependencyManager.require_now(self, feature)
#     220 if self:
#     221     return
# --> 222 raise MissingOptionalLibraryError(
#     223     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     224 )
#
# MissingOptionalLibraryError: "The 'pylatexenc' library is required to use 'MatplotlibDrawer'. You can install it with 'pip install pylatexenc'."

# %% [markdown]
# # Future Work
#
# - Testing module implementing Draper's adder and quantum phase estimation using approximate QFT.
# - Error quantification in terms of spectral norm
